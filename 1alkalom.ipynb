# %% [markdown]
# <a href="https://colab.research.google.com/github/HorvathAndor/Faktkurzus/blob/main/1alkalom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1ora

# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# File importalas

# %% [markdown]
# ##lokalis geprol beolvasas

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6e956c65-07fb-4878-944b-481e099c9137" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e956c65-07fb-4878-944b-481e099c9137">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving faktkurzus-1.jpg to faktkurzus-1.jpg

# %%
type(uploaded)
# Out:
# dict

# %%
uploaded.keys()
# Out:
# dict_keys(['faktkurzus-1.jpg'])

# %%
kep = plt.imread("faktkurzus-1.jpg")
plt.imshow(kep)

# %% [markdown]
# ## importalas drive-rol

# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
kep = plt.imread('/content/drive/My Drive/Fakt kurzus/faktkurzus-1.jpg')

# %%
plt.imshow(kep)

# %%
type(kep)
# Out:
# numpy.ndarray

# %%
kep.shape
# Out:
# (400, 600, 3)

# %% [markdown]
# 400X600 matrix harom melysegben

# %%
kep[:,:,1]
# Out:
# array([[  6,   6,   6, ..., 255, 255, 255],
#        [  6,   6,   6, ..., 255, 255, 255],
#        [  6,   6,   6, ..., 255, 255, 255],
#        ...,
#        [ 48,  49,  48, ..., 255, 255, 255],
#        [ 38,  48,  49, ..., 255, 255, 255],
#        [ 21,  38,  48, ..., 255, 255, 255]], dtype=uint8)

# %%
kep[:,:,0].mean()
# Out:
# 129.63522083333334

# %%
for channel in range(3):
  print(kep[:,:,channel].mean())
# Out:
# 129.63522083333334
# 129.62510833333334
# 129.63522083333334

# %%
plt.imshow(kep[:,:,1], cnap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-cd2c3c47eee1> in <module>()
# ----> 1 plt.imshow(kep[:,:,1], cnap = 'gray')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %%
kep[:,:,2].shape
# Out:
# (400, 600)

# %%
kep_red = kep.copy()

# %%
kep_red[:,:,(1,2)] = 0

# %%
plt.imshow(kep_red)

# %% [markdown]
# ha igy csinajuk akkor a kep mogott ott maradnak a dimenziok

# %%
kep_inverz = 255-kep

# %%
plt.imshow(kep_inverz)

# %%
kep_crop = kep[0:256,0:256,:]

# %%
plt.imshow(kep_crop)

# %%
from PIL import Image

# %%
kep = Image.open('/content/drive/My Drive/Fakt kurzus/faktkurzus-1.jpg')

# %%
type(kep)
# Out:
# PIL.WebPImagePlugin.WebPImageFile

# %%
print(kep.format)
print(kep.size)
print(kep.mode)
# Out:
# WEBP
# (600, 400)
# RGB

# %%
kep
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=600x400 at 0x7FE57174E2D0>

# %%
np_kep = np.asarray(kep)

# %%
Image.fromarray(np_kep)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FE5716B7A10>

# %%
kep.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7FE571888F50>

# %%
kep.resize(size=(100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FE573615CD0>

# %%
kep_to_save= kep.transpose(Image.FLIP_LEFT_RIGHT)

# %%
kep_to_save.save('/content/drive/My Drive/Fakt kurzus/faktkurzus-1uj.jpg')
